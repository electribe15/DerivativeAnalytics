# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import datetime as dt
from openbb_terminal.sdk import openbb

import webbrowser
import os

import pandas as pd
import quantstats as qs
import backtrader as bt

# %%
#download data to csv for backtrader
def openbb_data_to_bt_data(symbol, start_date, end_date):
    
    df = openbb.stocks.load(symbol, start_date=start_date, end_date=end_date)
    
    fn = f"{symbol.lower()}.csv"
    df.to_csv(fn)
    
    return bt.feeds.YahooFinanceCSVData(
        dataname=fn,
        fromdate=dt.datetime.strptime(start_date, '%Y-%m-%d'),
        todate=dt.datetime.strptime(end_date, '%Y-%m-%d')
    )

#This function downloads the data from the OpenBB SDK, converts it to a CSV, 
# and reads it into Backtrader’s YahooFinanceCSVData.

# %% [markdown]
# Build a backtest using Backtrader
#
# Fund managers report their holdings every month. They don’t want to tell investors they lost money on the latest meme stock. So they sell them before the reporting deadline and buy higher-quality assets, like bonds.
#
# You might be able to take advantage of this effect by buying bonds toward the end of the month and selling them at the beginning.
#
# Start with a simple helper function that gets the last day of the month.

# %%
def last_day_of_month(any_day):
    # The day 28 exists in every month. 4 days later, it's always next month
    next_month = any_day.replace(day=28) + dt.timedelta(days=4)
    
    # subtracting the number of the current day brings us back one month
    return (next_month - dt.timedelta(days=next_month.day)).day

# %% [markdown]
# Next, setup the Backtrader strategy. All Backtrader strategies are built as classes and inherit bt.Strategy.

# %%
#First, set up the strategy parameters. end_of_month is the first day 
#I want to be long SPY and start_of_month is the last day I want to be short.

#The strategy logic is in the next method.
#This code tests if there’s a position in the market. 
#If not, it checks if the current day is within the first week of the month 
#and creates a short position. Otherwise, if the current day is within the last week, 
#it creates a long position.

#The last step closes the open positions.The strategy closes the long position 
#if the current day is no longer within the last week of the month. 
#The strategy closes the short position if the current day is no longer within 
#the first week of the month.

# %%
class MonthlyFlows(bt.Strategy):
    
    params = (
        ("end_of_month", 23),
        ("start_of_month", 7),
    )
    
    def __init__(self):
        self.order = None
        self.dataclose = self.datas[0].close
        
    def notify_order(self, order):
        # No more orders
        self.order = None    
    
    def next(self):
        
        # Get today's date, day of month, and last day of current month
        dt_ = self.datas[0].datetime.date(0)
        dom = dt_.day
        ldm = last_day_of_month(dt_)
        
        # If an order is pending, exit
        if self.order:
            return
        
        # Check if we are in the market
        if not self.position:
            
            # We're in the first week of the month, sell
            if dom <= self.params.start_of_month:
                # Sell the entire portfolio
                self.order = self.order_target_percent(target=-1)
                
                print(f"Created SELL of {self.order.size} at {self.data_close[0]} on day {dom}")
            
            # We're in the last week of the month, buy
            if dom >= self.params.end_of_month:
                # Buy the entire portfolio
                self.order = self.order_target_percent(target=1)
                
                print(f"Created BUY of {self.order.size} {self.data_close[0]} on day {dom}")
        
        # We are not in the market
        else:
            
            # If we're long
            if self.position.size > 0:
                
                # And not within the last week of the month, close
                if not self.params.end_of_month <= dom <= ldm:
                    
                    print(f"Created CLOSE of {self.position.size} at {self.data_close[0]} on day {dom}")
                    self.order = self.order_target_percent(target=0.0)
            
            # If we're short
            if self.position.size < 0:
                
                # And not within the first week of the month, close
                if not 1 <= dom <= self.params.start_of_month:
                    
                    print(f"Created CLOSE of {self.position.size} at {self.data_close[0]} on day {dom}")
                    # self.order = self.close()
                    self.order = self.order_target_percent(target=0.0)

# %%
#run backtest
data = openbb_data_to_bt_data(
    "SPY", 
    start_date="2013-01-03",
    end_date="2023-11-04"
)
cerebro = bt.Cerebro(stdstats=False)
cerebro.adddata(data)
cerebro.broker.setcash(1000.0)
cerebro.addstrategy(MonthlyFlows)
cerebro.addobserver(bt.observers.Value)
cerebro.addanalyzer(
    bt.analyzers.Returns, _name="returns"
)
cerebro.addanalyzer(
    bt.analyzers.TimeReturn, _name="time_return"
)
backtest_result = cerebro.run()
# Out:
# Loading Daily data for SPY with starting period 2013-01-03.
# Created SELL of -8 at 119.71 on day 3
# Created CLOSE of -8 at 119.56 on day 8
# Created BUY of 8 122.7 on day 23
# Created CLOSE of 8 at 124.23 on day 1
# Created SELL of -8 at 122.84 on day 4
# Created CLOSE of -8 at 124.69 on day 8
# Created BUY of 8 122.39 on day 25
# Created CLOSE of 8 at 124.95 on day 1
# Created SELL of -8 at 125.61 on day 4
# Created CLOSE of -8 at 127.68 on day 8
# Created BUY of 7 127.84 on day 25
# Created CLOSE of 7 at 128.75 on day 1
# Created SELL of -7 at 129.39 on day 2
# Created CLOSE of -7 at 128.88 on day 8
# Created BUY of 7 130.18 on day 23
# Created CLOSE of 7 at 130.59 on day 1
# Created SELL of -7 at 131.81 on day 2
# Created CLOSE of -7 at 134.77 on day 8
# Created BUY of 7 136.51 on day 23
# Created CLOSE of 7 at 135.6 on day 3
# Created SELL of -7 at 134.95 on day 4
# Created CLOSE of -7 at 135.97 on day 10
# Created BUY of 7 130.27 on day 24
# Created CLOSE of 7 at 133.84 on day 1
# Created SELL of -7 at 133.71 on day 2
# Created CLOSE of -7 at 135.99 on day 8
# Created BUY of 7 140.29 on day 23
# Created CLOSE of 7 at 141.55 on day 1
# Created SELL of -7 at 141.79 on day 2
# Created CLOSE of -7 at 140.84 on day 8
# Created BUY of 7 138.2 on day 23
# Created CLOSE of 7 at 136.35 on day 3
# Created SELL of -7 at 137.48 on day 4
# Created CLOSE of -7 at 139.04 on day 9
# Created BUY of 6 141.63 on day 23
# Created CLOSE of 6 at 141.14 on day 1
# Created SELL of -6 at 141.01 on day 2
# Created CLOSE of -6 at 137.92 on day 8
# Created BUY of 6 145.5 on day 23
# Created CLOSE of 6 at 146.87 on day 1
# Created SELL of -6 at 147.38 on day 4
# Created CLOSE of -6 at 147.77 on day 8
# Created BUY of 6 150.55 on day 25
# Created CLOSE of 6 at 150.47 on day 2
# Created SELL of -6 at 149.82 on day 3
# Created CLOSE of -6 at 151.19 on day 9
# Created BUY of 6 152.96 on day 23
# Created CLOSE of 6 at 153.29 on day 2
# Created SELL of -6 at 153.26 on day 3
# Created CLOSE of -6 at 153.79 on day 8
# Created BUY of 6 153.18 on day 23
# Created CLOSE of 6 at 145.96 on day 3
# Created SELL of -6 at 146.98 on day 4
# Created CLOSE of -6 at 150.85 on day 10
# Created BUY of 5 154.96 on day 24
# Created CLOSE of 5 at 155.01 on day 3
# Created SELL of -5 at 157.19 on day 4
# Created CLOSE of -5 at 157.68 on day 10
# Created BUY of 5 156.08 on day 24
# Created CLOSE of 5 at 158.45 on day 1
# Created SELL of -5 at 158.98 on day 2
# Created CLOSE of -5 at 155.8 on day 8
# Created BUY of 5 157.78 on day 23
# Created CLOSE of 5 at 158.52 on day 1
# Created SELL of -5 at 158.29 on day 2
# Created CLOSE of -5 at 157.97 on day 8
# Created BUY of 5 160.22 on day 23
# Created CLOSE of 5 at 162.36 on day 2
# Created SELL of -5 at 162.28 on day 3
# Created CLOSE of -5 at 164.62 on day 9
# Created BUY of 5 165.66 on day 23
# Created CLOSE of 5 at 166.64 on day 1
# Created SELL of -5 at 166.8 on day 2
# Created CLOSE of -5 at 165.97 on day 8
# Created BUY of 5 168.0 on day 23
# Created CLOSE of 5 at 162.8 on day 1
# Created SELL of -5 at 163.98 on day 4
# Created CLOSE of -5 at 163.43 on day 8
# Created BUY of 5 169.32 on day 25
# Created CLOSE of 5 at 169.66 on day 2
# Created SELL of -5 at 169.57 on day 3
# Created CLOSE of -5 at 169.65 on day 8
# Created BUY of 5 168.25 on day 23
# Created CLOSE of 5 at 165.14 on day 1
# Created SELL of -5 at 165.16 on day 2
# Created CLOSE of -5 at 167.08 on day 8
# Created BUY of 5 165.63 on day 23
# Created CLOSE of 5 at 171.44 on day 3
# Created SELL of -5 at 170.85 on day 4
# Created CLOSE of -5 at 173.32 on day 10
# Created BUY of 5 176.11 on day 24
# Created CLOSE of 5 at 174.83 on day 1
# Created SELL of -5 at 175.96 on day 2
# Created CLOSE of -5 at 175.55 on day 8
# Created BUY of 5 177.5 on day 23
# Created CLOSE of 5 at 175.52 on day 2
# Created SELL of -5 at 172.35 on day 5
# Created CLOSE of -5 at 175.92 on day 8
# Created BUY of 5 175.12 on day 23
# Created CLOSE of 5 at 172.52 on day 2
# Created SELL of -5 at 175.01 on day 3
# Created CLOSE of -5 at 174.83 on day 9
# Created BUY of 4 180.45 on day 23
# Created CLOSE of 4 at 181.12 on day 2
# Created SELL of -4 at 180.38 on day 3
# Created CLOSE of -4 at 178.02 on day 9
# Created BUY of 4 180.22 on day 23
# Created CLOSE of 4 at 176.53 on day 1
# Created SELL of -4 at 177.17 on day 2
# Created CLOSE of -4 at 178.49 on day 8
# Created BUY of 4 181.22 on day 23
# Created CLOSE of 4 at 180.84 on day 1
# Created SELL of -4 at 181.35 on day 4
# Created CLOSE of -4 at 181.61 on day 8
# Created BUY of 4 180.82 on day 26
# Created CLOSE of 4 at 181.57 on day 1
# Created SELL of -4 at 181.39 on day 2
# Created CLOSE of -4 at 178.92 on day 8
# Created BUY of 4 182.86 on day 23
# Created CLOSE of 4 at 178.94 on day 1
# Created SELL of -4 at 178.78 on day 2
# Created CLOSE of -4 at 176.38 on day 8
# Created BUY of 4 181.25 on day 23
# Created CLOSE of 4 at 180.92 on day 3
# Created SELL of -4 at 180.56 on day 4
# Created CLOSE of -4 at 181.59 on day 10
# Created BUY of 5 163.42 on day 24
# Created CLOSE of 5 at 165.38 on day 1
# Created SELL of -5 at 168.52 on day 2
# Created CLOSE of -5 at 170.26 on day 8
# Created BUY of 4 167.82 on day 23
# Created CLOSE of 4 at 166.55 on day 1
# Created SELL of -4 at 169.04 on day 2
# Created CLOSE of -4 at 174.42 on day 8
# Created BUY of 4 179.88 on day 23
# Created CLOSE of 4 at 182.38 on day 2
# Created SELL of -4 at 182.91 on day 3
# Created CLOSE of -4 at 180.37 on day 9
# Created BUY of 4 181.23 on day 23
# Created CLOSE of 4 at 182.63 on day 1
# Created SELL of -4 at 180.76 on day 2
# Created CLOSE of -4 at 179.4 on day 8
# Created BUY of 4 179.65 on day 23
# Created CLOSE of 4 at 175.29 on day 4
# Created SELL of -4 at 175.59 on day 5
# Created CLOSE of -4 at 167.36 on day 8
# Created BUY of 5 163.62 on day 25
# Created CLOSE of 5 at 168.87 on day 1
# Created SELL of -5 at 165.82 on day 2
# Created CLOSE of -5 at 161.69 on day 8
# Created BUY of 5 167.71 on day 23
# Created CLOSE of 5 at 172.75 on day 1
# Created SELL of -5 at 173.53 on day 2
# Created CLOSE of -5 at 173.01 on day 8
# Created BUY of 5 178.12 on day 23
# Created CLOSE of 5 at 181.37 on day 1
# Created SELL of -5 at 180.78 on day 4
# Created CLOSE of -5 at 179.25 on day 8
# Created BUY of 5 182.85 on day 25
# Created CLOSE of 5 at 182.29 on day 2
# Created SELL of -5 at 180.7 on day 3
# Created CLOSE of -5 at 180.46 on day 9
# Created BUY of 5 179.87 on day 23
# Created CLOSE of 5 at 184.3 on day 1
# Created SELL of -5 at 184.86 on day 2
# Created CLOSE of -5 at 186.14 on day 8
# Created BUY of 5 185.74 on day 23
# Created CLOSE of 5 at 184.95 on day 1
# Created SELL of -5 at 183.62 on day 5
# Created CLOSE of -5 at 187.36 on day 8
# Created BUY of 4 190.88 on day 25
# Created CLOSE of 4 at 191.14 on day 1
# Created SELL of -4 at 189.91 on day 2
# Created CLOSE of -4 at 192.12 on day 8
# Created BUY of 4 192.93 on day 23
# Created CLOSE of 4 at 191.54 on day 1
# Created SELL of -4 at 192.4 on day 2
# Created CLOSE of -4 at 192.52 on day 8
# Created BUY of 4 191.26 on day 23
# Created CLOSE of 4 at 191.08 on day 3
# Created SELL of -4 at 190.1 on day 4
# Created CLOSE of -4 at 191.41 on day 10
# Created BUY of 4 190.29 on day 24
# Created CLOSE of 4 at 186.85 on day 1
# Created SELL of -5 at 185.73 on day 2
# Created CLOSE of -5 at 189.6 on day 8
# Created BUY of 4 195.43 on day 23
# Created CLOSE of 4 at 194.43 on day 1
# Created SELL of -4 at 194.53 on day 2
# Created CLOSE of -4 at 199.37 on day 8
# Created BUY of 4 201.05 on day 23
# Created CLOSE of 4 at 200.63 on day 3
# Created SELL of -4 at 201.82 on day 4
# Created CLOSE of -4 at 201.72 on day 9
# Created BUY of 4 201.44 on day 23
# Created CLOSE of 4 at 202.75 on day 1
# Created SELL of -4 at 202.88 on day 2
# Created CLOSE of -4 at 204.19 on day 8
# Created BUY of 4 210.61 on day 23
# Created CLOSE of 4 at 213.58 on day 1
# Created SELL of -4 at 212.24 on day 2
# Created CLOSE of -4 at 210.71 on day 8
# Created BUY of 4 209.37 on day 23
# Created CLOSE of 4 at 210.53 on day 3
# Created SELL of -4 at 210.66 on day 4
# Created CLOSE of -4 at 210.54 on day 10
# Created BUY of 4 212.18 on day 24
# Created CLOSE of 4 at 213.53 on day 1
# Created SELL of -4 at 213.61 on day 2
# Created CLOSE of -4 at 214.4 on day 8
# Created BUY of 4 214.75 on day 23
# Created CLOSE of 4 at 217.71 on day 1
# Created SELL of -4 at 218.44 on day 2
# Created CLOSE of -4 at 218.09 on day 8
# Created BUY of 4 218.57 on day 23
# Created CLOSE of 4 at 217.74 on day 3
# Created SELL of -4 at 218.24 on day 5
# Created CLOSE of -4 at 217.88 on day 10
# Created BUY of 4 221.89 on day 24
# Created CLOSE of 4 at 222.33 on day 1
# Created SELL of -4 at 222.44 on day 2
# Created CLOSE of -4 at 222.28 on day 8
# Created BUY of 4 219.85 on day 23
# Created CLOSE of 4 at 222.8 on day 1
# Created SELL of -4 at 221.2 on day 5
# Created CLOSE of -4 at 221.67 on day 8
# Created BUY of 4 224.89 on day 25
# Created CLOSE of 4 at 227.96 on day 2
# Created SELL of -4 at 228.44 on day 3
# Created CLOSE of -4 at 229.43 on day 9
# Created BUY of 4 231.38 on day 23
# Created CLOSE of 4 at 232.63 on day 1
# Created SELL of -4 at 232.72 on day 2
# Created CLOSE of -4 at 234.09 on day 8
# Created BUY of 4 235.22 on day 24
# Created CLOSE of 4 at 238.92 on day 1
# Created SELL of -4 at 238.63 on day 4
# Created CLOSE of -4 at 239.87 on day 8
# Created BUY of 3 242.62 on day 26
# Created CLOSE of 3 at 244.06 on day 2
# Created SELL of -3 at 245.6 on day 3
# Created CLOSE of -3 at 248.73 on day 8
# Created BUY of 3 257.24 on day 23
# Created CLOSE of 3 at 255.69 on day 1
# Created SELL of -3 at 250.12 on day 2
# Created CLOSE of -3 at 233.94 on day 8
# Created BUY of 3 249.45 on day 23
# Created CLOSE of 3 at 243.09 on day 1
# Created SELL of -3 at 244.34 on day 2
# Created CLOSE of -3 at 248.9 on day 8
# Created BUY of 3 235.26 on day 23
# Created CLOSE of 3 at 234.73 on day 2
# Created SELL of -3 at 237.74 on day 3
# Created CLOSE of -3 at 237.95 on day 9
# Created BUY of 3 243.03 on day 23
# Created CLOSE of 3 at 241.58 on day 1
# Created SELL of -3 at 239.96 on day 2
# Created CLOSE of -3 at 243.35 on day 8
# Created BUY of 3 249.22 on day 23
# Created CLOSE of 3 at 249.44 on day 1
# Created SELL of -3 at 250.62 on day 4
# Created CLOSE of -3 at 253.62 on day 8
# Created BUY of 3 248.18 on day 25
# Created CLOSE of 3 at 248.97 on day 2
# Created SELL of -3 at 248.09 on day 3
# Created CLOSE of -3 at 254.5 on day 9
# Created BUY of 3 256.6 on day 23
# Created CLOSE of 3 at 257.21 on day 1
# Created SELL of -3 at 258.61 on day 2
# Created CLOSE of -3 at 261.42 on day 8
# Created BUY of 3 261.72 on day 23
# Created CLOSE of 3 at 265.4 on day 4
# Created SELL of -3 at 264.69 on day 5
# Created CLOSE of -3 at 263.84 on day 10
# Created BUY of 3 267.72 on day 24
# Created CLOSE of 3 at 268.37 on day 1
# Created SELL of -3 at 268.21 on day 2
# Created CLOSE of -3 at 264.77 on day 8
# Created BUY of 3 251.7 on day 23
# Created CLOSE of 3 at 251.61 on day 1
# Created SELL of -3 at 250.12 on day 2
# Created CLOSE of -3 at 258.04 on day 8
# Created BUY of 3 242.17 on day 23
# Created CLOSE of 3 at 256.94 on day 3
# Created SELL of -3 at 248.61 on day 4
# Created CLOSE of -3 at 242.93 on day 10
# Created BUY of 4 216.84 on day 24
# Created CLOSE of 4 at 231.49 on day 2
# Created SELL of -4 at 225.97 on day 3
# Created CLOSE of -4 at 237.59 on day 8
# Created BUY of 3 243.73 on day 23
# Created CLOSE of 3 at 249.89 on day 1
# Created SELL of -3 at 251.65 on day 4
# Created CLOSE of -3 at 250.27 on day 8
# Created BUY of 3 258.64 on day 25
# Created CLOSE of 3 at 259.47 on day 1
# Created SELL of -3 at 258.53 on day 4
# Created CLOSE of -3 at 253.96 on day 8
# Created BUY of 3 259.33 on day 25
# Created CLOSE of 3 at 265.64 on day 1
# Created SELL of -3 at 265.77 on day 2
# Created CLOSE of -3 at 268.4 on day 8
# Created BUY of 3 272.2 on day 23
# Created CLOSE of 3 at 271.2 on day 1
# Created SELL of -3 at 270.62 on day 2
# Created CLOSE of -3 at 267.22 on day 8
# Created BUY of 3 262.21 on day 23
# Created CLOSE of 3 at 255.18 on day 3
# Created SELL of -3 at 260.72 on day 4
# Created CLOSE of -3 at 268.56 on day 10
# Created BUY of 3 274.23 on day 24
# Created CLOSE of 3 at 276.12 on day 1
# Created SELL of -3 at 276.84 on day 2
# Created CLOSE of -3 at 277.2 on day 8
# Created BUY of 3 280.2 on day 23
# Created CLOSE of 3 at 275.35 on day 1
# Created SELL of -3 at 273.28 on day 2
# Created CLOSE of -3 at 274.21 on day 8
# Created BUY of 3 266.02 on day 23
# Created CLOSE of 3 at 271.52 on day 3
# Created SELL of -3 at 274.6 on day 4
# Created CLOSE of -3 at 278.49 on day 9
# Created BUY of 3 279.78 on day 23
# Created CLOSE of 3 at 275.12 on day 1
# Created SELL of -3 at 270.26 on day 2
# Created CLOSE of -3 at 270.7 on day 8
# Created BUY of 3 281.35 on day 23
# Created CLOSE of 3 at 287.22 on day 1
# Created SELL of -3 at 288.38 on day 4
# Created CLOSE of -3 at 289.85 on day 8
# Created BUY of 3 294.01 on day 25
# Created CLOSE of 3 at 292.38 on day 2
# Created SELL of -3 at 290.42 on day 3
# Created CLOSE of -3 at 294.49 on day 9
# Created BUY of 2 302.85 on day 23
# Created CLOSE of 2 at 306.3 on day 2
# Created SELL of -2 at 303.98 on day 3
# Created CLOSE of -2 at 305.9 on day 8
# Created BUY of 2 312.75 on day 23
# Created CLOSE of 2 at 305.59 on day 3
# Created SELL of -2 at 310.25 on day 4
# Created CLOSE of -2 at 315.54 on day 10
# Created BUY of 2 303.99 on day 24
# Created CLOSE of 2 at 291.42 on day 2
# Created SELL of -2 at 283.07 on day 3
# Created CLOSE of -2 at 258.55 on day 9
# Created BUY of 4 211.44 on day 23
# Created BUY of 3 230.6 on day 24
# Created CLOSE of 3 at 233.44 on day 1
# Created SELL of -3 at 238.83 on day 2
# Created CLOSE of -3 at 259.88 on day 8
# Created BUY of 2 264.67 on day 23
# Created CLOSE of 2 at 268.19 on day 1
# Created SELL of -2 at 268.93 on day 4
# Created CLOSE of -2 at 277.34 on day 8
# Created BUY of 2 283.64 on day 26
# Created CLOSE of 2 at 289.77 on day 1
# Created SELL of -2 at 292.17 on day 2
# Created CLOSE of -2 at 306.51 on day 8
# Created BUY of 2 297.24 on day 23
# Created CLOSE of 2 at 295.78 on day 1
# Created SELL of -2 at 297.41 on day 2
# Created CLOSE of -2 at 301.17 on day 8
# Created BUY of 2 307.63 on day 23
# Created CLOSE of 2 at 313.19 on day 3
# Created SELL of -2 at 314.4 on day 4
# Created CLOSE of -2 at 319.64 on day 10
# Created BUY of 2 326.65 on day 24
# Created CLOSE of 2 at 335.87 on day 1
# Created SELL of -2 at 340.72 on day 2
# Created CLOSE of -2 at 317.4 on day 8
# Created BUY of 2 308.56 on day 23
# Created CLOSE of 2 at 322.33 on day 1
# Created SELL of -2 at 319.27 on day 2
# Created CLOSE of -2 at 328.78 on day 8
# Created BUY of 2 330.69 on day 23
# Created CLOSE of 2 at 315.79 on day 2
# Created SELL of -2 at 321.36 on day 3
# Created CLOSE of -2 at 339.09 on day 9
# Created BUY of 2 341.86 on day 23
# Created CLOSE of 2 at 350.04 on day 1
# Created SELL of -2 at 350.78 on day 2
# Created CLOSE of -2 at 354.01 on day 8
# Created BUY of 2 353.03 on day 23
# Created CLOSE of 2 at 354.2 on day 4
# Created SELL of -2 at 356.64 on day 5
# Created CLOSE of -2 at 366.17 on day 8
# Created BUY of 2 369.18 on day 25
# Created CLOSE of 2 at 361.34 on day 1
# Created SELL of -2 at 366.45 on day 2
# Created CLOSE of -2 at 375.06 on day 8
# Created BUY of 2 372.17 on day 23
# Created CLOSE of 2 at 374.16 on day 1
# Created SELL of -2 at 371.25 on day 2
# Created CLOSE of -2 at 366.62 on day 8
# Created BUY of 2 375.31 on day 23
# Created CLOSE of 2 at 386.02 on day 1
# Created SELL of -2 at 391.56 on day 5
# Created CLOSE of -2 at 393.64 on day 8
# Created BUY of 1 401.56 on day 23
# Created CLOSE of 1 at 402.97 on day 3
# Created SELL of -1 at 400.48 on day 4
# Created CLOSE of -1 at 402.72 on day 10
# Created BUY of 1 403.9 on day 24
# Created CLOSE of 1 at 404.38 on day 1
# Created SELL of -1 at 405.02 on day 2
# Created CLOSE of -1 at 406.9 on day 8
# Created BUY of 1 408.54 on day 23
# Created CLOSE of 1 at 416.11 on day 1
# Created SELL of -1 at 419.29 on day 2
# Created CLOSE of -1 at 416.58 on day 8
# Created BUY of 1 425.3 on day 23
# Created CLOSE of 1 at 423.03 on day 2
# Created SELL of -1 at 426.47 on day 3
# Created CLOSE of -1 at 427.42 on day 9
# Created BUY of 1 432.38 on day 23
# Created CLOSE of 1 at 436.77 on day 1
# Created SELL of -1 at 438.11 on day 2
# Created CLOSE of -1 at 435.91 on day 8
# Created BUY of 1 429.81 on day 23
# Created CLOSE of 1 at 421.14 on day 1
# Created SELL of -1 at 415.71 on day 4
# Created CLOSE of -1 at 424.65 on day 8
# Created BUY of 1 441.8 on day 25
# Created CLOSE of 1 at 446.16 on day 1
# Created SELL of -1 at 447.96 on day 2
# Created CLOSE of -1 at 454.78 on day 8
# Created BUY of 1 454.06 on day 23
# Created CLOSE of 1 at 436.91 on day 1
# Created SELL of -1 at 443.6 on day 2
# Created CLOSE of -1 at 455.35 on day 8
# Created BUY of 1 458.0 on day 23
# Created CLOSE of 1 at 464.92 on day 3
# Created SELL of -1 at 464.77 on day 4
# Created CLOSE of -1 at 453.05 on day 10
# Created BUY of 1 428.07 on day 24
# Created CLOSE of 1 at 440.83 on day 1
# Created SELL of -1 at 445.11 on day 2
# Created CLOSE of -1 at 438.87 on day 8
# Created BUY of 1 410.66 on day 23
# Created CLOSE of 1 at 418.47 on day 1
# Created SELL of -1 at 426.17 on day 2
# Created CLOSE of -1 at 405.11 on day 8
# Created BUY of 1 433.26 on day 23
# Created CLOSE of 1 at 442.17 on day 1
# Created SELL of -1 at 445.95 on day 4
# Created CLOSE of -1 at 436.94 on day 8
# Created BUY of 2 418.34 on day 25
# Created CLOSE of 2 at 404.64 on day 2
# Created SELL of -2 at 406.49 on day 3
# Created CLOSE of -2 at 388.72 on day 9
# Created BUY of 2 387.5 on day 23
# Created CLOSE of 2 at 399.87 on day 1
# Created SELL of -2 at 407.48 on day 2
# Created CLOSE of -2 at 401.46 on day 8
# Created BUY of 2 370.68 on day 23
# Created CLOSE of 2 at 373.8 on day 1
# Created SELL of -2 at 374.5 on day 5
# Created CLOSE of -2 at 381.08 on day 8
# Created BUY of 2 387.85 on day 25
# Created CLOSE of 2 at 402.75 on day 1
# Created SELL of -2 at 400.09 on day 2
# Created CLOSE of -2 at 404.93 on day 8
# Created BUY of 2 404.3 on day 23
# Created CLOSE of 2 at 388.68 on day 1
# Created SELL of -2 at 384.58 on day 2
# Created CLOSE of -2 at 392.56 on day 8
# Created BUY of 2 362.25 on day 23
# Created CLOSE of 2 at 360.93 on day 3
# Created SELL of -2 at 372.11 on day 4
# Created CLOSE of -2 at 354.44 on day 10
# Created BUY of 2 373.0 on day 24
# Created CLOSE of 2 at 378.56 on day 1
# Created SELL of -2 at 369.06 on day 2
# Created CLOSE of -2 at 376.08 on day 8
# Created BUY of 2 396.18 on day 23
# Created CLOSE of 2 at 401.07 on day 1
# Created SELL of -2 at 400.6 on day 2
# Created CLOSE of -2 at 390.1 on day 8
# Created BUY of 2 378.71 on day 23
# Created CLOSE of 2 at 376.64 on day 3
# Created SELL of -2 at 379.55 on day 4
# Created CLOSE of -2 at 383.6 on day 9
# Created BUY of 2 396.23 on day 23
# Created CLOSE of 2 at 406.29 on day 1
# Created SELL of -2 at 412.2 on day 2
# Created CLOSE of -2 at 406.14 on day 8
# Created BUY of 2 396.26 on day 23
# Created CLOSE of 2 at 390.41 on day 1
# Created SELL of -2 at 393.44 on day 2
# Created CLOSE of -2 at 394.54 on day 8
# Created BUY of 2 390.34 on day 23
# Created CLOSE of 2 at 407.99 on day 3
# Created SELL of -2 at 405.73 on day 4
# Created CLOSE of -2 at 406.66 on day 10
# Created BUY of 2 409.66 on day 24
# Created CLOSE of 2 at 412.52 on day 1
# Created SELL of -2 at 407.88 on day 2
# Created CLOSE of -2 at 409.77 on day 8
# Created BUY of 2 411.11 on day 23
# Created CLOSE of 2 at 418.78 on day 1
# Created SELL of -2 at 424.84 on day 2
# Created CLOSE of -2 at 426.04 on day 8
# Created BUY of 2 431.69 on day 23
# Created CLOSE of 2 at 442.23 on day 3
# Created SELL of -2 at 441.57 on day 5
# Created CLOSE of -2 at 438.11 on day 10
# Created BUY of 2 452.6 on day 24
# Created CLOSE of 2 at 454.88 on day 1
# Created SELL of -2 at 448.55 on day 2
# Created CLOSE of -2 at 447.17 on day 8
# Created BUY of 2 441.47 on day 23
# Created CLOSE of 2 at 449.6 on day 1
# Created SELL of -2 at 447.66 on day 5
# Created CLOSE of -2 at 443.95 on day 8
# Created BUY of 2 432.23 on day 25
# Created CLOSE of 2 at 427.31 on day 2
# Created SELL of -2 at 421.59 on day 3
# Created CLOSE of -2 at 432.29 on day 9
# Created BUY of 2 420.46 on day 23
# Created CLOSE of 2 at 422.66 on day 1
# Created SELL of -2 at 430.76 on day 2

# %% [markdown]
# The first step is to create a backtesting engine (Backtrader calls it Cerebro). Then add the data, initial cash, and strategy logic. Backtrader has built-in observers that track variables and performance throughout the backtest.
#
# After setting up the backtest, run it.
#
# The last step is to convert the results into a pandas DataFrame.

# %%
# Get the strategy returns as a dictionary
returns_dict= backtest_result[0].analyzers.time_return.get_analysis()

# Convert the dictionary to a DataFrame

# %%
# Convert the dictionary to a DataFrame
returns_df = pd.DataFrame(list(returns_dict.items()), columns=["date", "returns"])

# Convert the 'date' column to datetime
returns_df['date'] = pd.to_datetime(returns_df['date'])

# Set the 'date' column as the index
returns_df = returns_df.set_index('date')

# %%
returns_series = returns_df['returns']

# %%
print(type(returns_series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(returns_series.head())
# Out:
# date
# 2013-01-03    0.000000
# 2013-01-04   -0.002640
# 2013-01-07    0.002647
# 2013-01-08    0.002720
# 2013-01-09   -0.002074
# Name: returns, dtype: float64

# %% [markdown]
#  Assess the results using key performance metrics
#
# Trading takes time, money, and effort. To make sure you’re better off not being long SPY, compare the strategy results to a long-only strategy.
#
# QuantStats makes it easy.
#
# QuantStats is a library jam-packed with trading performance and risk metrics. One of the best parts of Backtrader is that it works well with QuantStats.

# %%
bench = openbb.stocks.load(
    "SPY",
    start_date="2013-01-02",
    end_date="2023-11-03"
)["Adj Close"].pct_change()

if not isinstance(bench.index, pd.DatetimeIndex):
    bench.index = pd.to_datetime(bench.index)
# Out:
# Loading Daily data for SPY with starting period 2013-01-02.

# %%
# Generate the report
qs.reports.html(returns_series, benchmark_rets=bench, output="stats.html")
webbrowser.open('file://' + os.path.realpath('stats.html'))
# Out:
# True

# %%
# Out:
# True
